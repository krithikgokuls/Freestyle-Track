# %% [markdown]
# # AI Agent for Flight Booking, Cancellation & Immigration Notifications (Freestyle Track)\nShort abstract and minimal runnable example included.

# %%
# Install required packages (run in shell)\n!pip install openai flask sentence-transformers faiss-cpu python-dotenv

# %%
# Example: run a simplified local RAG + LLM call (fill keys and run)\nfrom IPython.display import JSON\nOPENAI_API_KEY = 'YOUR_OPENAI_API_KEY'\nGOOGLE_API_KEY = 'YOUR_GOOGLE_API_KEY'\nprint('Fill your keys and run the Flask app separately.')
